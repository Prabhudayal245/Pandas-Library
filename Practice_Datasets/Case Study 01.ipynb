# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\HP\Downloads\\archive (1)\\Ecommerce Purchases")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\HP\AppData\Local\Temp\ipykernel_16872\2114349057.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv("C:\\Users\\HP\Downloads\\archive (1)\\Ecommerce Purchases")

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
df.tail()
# Out:
#                                                 Address    Lot AM or PM  \
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                        Company       Credit Card CC Exp Date  \
# 9995             Randall-Sloan   342945015358701       03/22
# 9996  Hale, Collins and Wilson   210033169205009       07/25
# ...

# %%
df["AM or PM"]=df["AM or PM"].astype('category')
df["CC Provider"]=df["CC Provider"].astype("category")
df["Job"]=df["Job"].astype("category")
df["Language"]=df["Language"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  category
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  category
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  category
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  category
#  13  Purchase Price    10000 non-null  float64
# dtypes: category(4), float64(1), int64(2), object(7)
# memory usage: 852.1+ KB

# %%
df.size
# Out:
# 140000

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Address               object
# Lot                   object
# AM or PM            category
# Browser Info          object
# Company               object
# Credit Card            int64
# CC Exp Date           object
# CC Security Code       int64
# CC Provider         category
# Email                 object
# Job                 category
# IP Address            object
# Language            category
# Purchase Price       float64
# dtype: object

# %% [markdown]
# ## Questions

# %%
# 1. Display Top 10 Rows of The Dataset
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
# 2. Display last 10 Rows of The Dataset
df.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
# 3.Check data type of each column
# df.info()
df.dtypes
# Out:
# Address               object
# Lot                   object
# AM or PM            category
# Browser Info          object
# Company               object
# Credit Card            int64
# CC Exp Date           object
# CC Security Code       int64
# CC Provider         category
# Email                 object
# Job                 category
# IP Address            object
# Language            category
# Purchase Price       float64
# dtype: object

# %%
# 4.How many rows and columns are in our dataset 
df.shape
# Out:
# (10000, 14)

# %%
# 5.Check null values in the dataset
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
for i in df.columns:
    print(f"The null values in {i} column is {df[i].isnull().sum()}")
# Out:
# The null values in Address column is 0
# The null values in Lot column is 0
# The null values in AM or PM column is 0
# The null values in Browser Info column is 0
# The null values in Company column is 0
# The null values in Credit Card column is 0
# The null values in CC Exp Date column is 0
# The null values in CC Security Code column is 0
# The null values in CC Provider column is 0
# The null values in Email column is 0
# The null values in Job column is 0
# The null values in IP Address column is 0
# The null values in Language column is 0
# The null values in Purchase Price column is 0

# %%
# 6.Highest and lowest purchase price 
df.head(3)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2       Simpson, Williams and Pham      675957666125       08/19
#
#    CC Security Code   CC Provider                           Email  \
# 0               900  JCB 16 digit               pdunlap@yahoo.com
# 1               561    Mastercard              anthony41@reed.com
# ...

# %%
max_purchase=df['Purchase Price'].max()
print(f"The highest purchase price is {max_purchase}")
# Out:
# The highest purchase price is 99.99

# %%
min_purchase=df['Purchase Price'].min()
print(f"The lowest purchase price is {min_purchase}")
# Out:
# The lowest purchase price is 0.0

# %%
# 7.Average purchase Price
avg_purchase=df['Purchase Price'].mean()
print(f"The average Purchase Price is {avg_purchase}")
# Out:
# The average Purchase Price is 50.347302

# %%
df.sample(6)
# Out:
#                                                 Address    Lot AM or PM  \
# 5368    096 Anderson Club Apt. 728\nLisahaven, GU 69703  77 WB       AM
# 3578    708 Thomas Bypass Apt. 632\nMyersland, VT 19437  20 KY       AM
# 8989           285 Flynn Court\nMichellehaven, NV 76448  55 mF       PM
# 8086       308 Kim Common Apt. 774\nEast Luis, UT 95485  64 KF       PM
# 1536       455 Chelsea Pass\nBirdborough, UT 92451-6248  90 td       AM
# 6630  905 Michael Vista Apt. 970\nRussellbury, IN 35...  37 No       AM
#
#                                            Browser Info  \
# 5368  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_5_8...
# 3578  Opera/9.62.(Windows CE; sl-SI) Presto/2.9.162 ...
# 8989  Mozilla/5.0 (X11; Linux i686) AppleWebKit/5360...
# 8086  Opera/8.85.(Windows NT 5.01; it-IT) Presto/2.9...
# 1536  Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...
# 6630  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_6_5...
#
#                        Company       Credit Card CC Exp Date  \
# ...

# %%
# 8.how many people have french 'fr' as their language
df[df['Language']=='fr'].shape[0]
# Out:
# 1097

# %%
# 9.Job title contains Enginner
df[df['Job'].str.contains('engineer',case=False)].shape[0]
# Out:
# 984

# %%
# 10.Find The Email of the person with the following IP Address: 132.207.160.22
mask1=df[df['IP Address']=='132.207.160.22']
print(f"The Email of following IP Address 132.207.160.22 is:{mask1['Email']}")
# Out:
# The Email of following IP Address 132.207.160.22 is:2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
# 11.How many People have Mastercard as their Credit Card Provider and made a purchase above 50?
df.loc[(df['CC Provider']=='Mastercard') & (df["Purchase Price"]>50)].shape[0]
# Out:
# 405

# %%
# 12.Find the email of the person with the following Credit Card Number: 4664825258997302
df[df['Credit Card']==4664825258997302]['Email']
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %%
# 13.How many people purchase during the AM and how many people purchase during PM?
# Method 1
mask2=df[df['AM or PM']=='AM'].shape[0]
print(f"The people how purchase during the AM is {mask2}")

mask3=df[df["AM or PM"]=='PM'].shape[0]
print(f"The people how purchase during the PM is {mask3}")

print(mask2+mask3)
# Out:
# The people how purchase during the AM is 4932
# The people how purchase during the PM is 5068
# 10000

# %%
# Method 2
df["AM or PM"].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
# 14.How many people have a credit card that expires in 2020?
# method 1
def func():
    count=0
    for date in df["CC Exp Date"]:
        if date.split('/')[1]=='20':
            count=count+1
    print(count)

func()
# Out:
# 988

# %%
# method 2
df[df['CC Exp Date'].apply(lambda x:x[3:]=='20')].shape[0]
# Out:
# 988

# %%
# 15.What are the top 5 most popular email providers (e.g. gmail.com, yahoo.com, etc...)
list=[]
for email in df['Email']:
    emails=email.split('@')[1]
    list.append(emails)

df['temp']=list

# %%
df['temp'].value_counts(ascending=False).head(5)
# Out:
# temp
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
# method 2
df['Email'].apply(lambda X:X.split('@')[1]).value_counts().head()
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
split=lambda x:x.split('@')[1]
df['Email'].apply(split).value_counts().head()
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...
