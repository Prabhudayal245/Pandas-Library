# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\HP\\Downloads\\train.csv")

# %%
# Display the top 5 rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#  Display last 3 rows
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
# . Find Shape of Our Dataset (Number of Rows & Number of Columns)
df.shape
print(f"Numbe of rows is {df.shape[0]}")
print(f"Numbe of columns is {df.shape[1]}")
# Out:
# Numbe of rows is 891
# Numbe of columns is 12

# %%
#  Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Get Overall Statistics About The Dataframe
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Data Filtering
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[["Name","Age","Sex","Survived"]]
# Out:
#                                                   Name   Age     Sex  Survived
# 0                              Braund, Mr. Owen Harris  22.0    male         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female         1
# 2                               Heikkinen, Miss. Laina  26.0  female         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female         1
# 4                             Allen, Mr. William Henry  35.0    male         0
# ..                                                 ...   ...     ...       ...
# 886                              Montvila, Rev. Juozas  27.0    male         0
# 887                       Graham, Miss. Margaret Edith  19.0  female         1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female         0
# 889                              Behr, Mr. Karl Howell  26.0    male         1
# 890                                Dooley, Mr. Patrick  32.0    male         0
#
# [891 rows x 4 columns]

# %%
df[df['Sex']=='female'].head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
# How many pecentage of person are survived 
mask1=df[df['Survived']==1]
sur=(mask1.shape[0]/df.shape[0])*100
print(f"The percentage of person who survived in titanic {sur}")
# Out:
# The percentage of person who survived in titanic 38.38383838383838

# %%
# Check Null Values In The Dataset
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#  by vitualization
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# percentage of null values in age column
age_null=(df['Age'].isnull().sum()/df['Age'].shape[0])*100
print(f"The null values in age column is {age_null}%")
# Out:
# The null values in age column is 19.865319865319865%

# %%
# percentage of null values in cabin column
cabin_null=(df['Cabin'].isnull().sum()/df['Cabin'].shape[0])*100
print(f"The null values in cabin column is {cabin_null}%")
# Out:
# The null values in cabin column is 77.10437710437711%

# %%
# Drop column 
df.drop('Cabin',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
#  Handle missing values
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df['Embarked'].fillna('S',inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20460\3895404187.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna('S',inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
df['Age'].fillna(df["Age"].mean(),inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20460\2703313926.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df["Age"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#  change the male and female into 0 and 1
x=df['Sex'].replace({'male':0,'female':1})
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20460\2602843683.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x=df['Sex'].replace({'male':0,'female':1})

# %%
df.insert(5,'Gender',x)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender  \
# 0                              Braund, Mr. Owen Harris    male       0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       1
# 2                               Heikkinen, Miss. Laina  female       1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       1
# 4                             Allen, Mr. William Henry    male       0
# ..                                                 ...     ...     ...
# ...

# %% [markdown]
# #  Univeriate analysis

# %%
#  How Many People Survived And How Many Died?
print(f"There are {df[df['Survived']==1].shape[0]} person is survived")
print(f"There are {df[df['Survived']==0].shape[0]} person is Died")
# Out:
# There are 342 person is survived
# There are 549 person is Died

# %%
# another method 
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# How Many Passengers Were In First Class, Second Class, and Third Class?
df.head(2)
print(f"There are {df[df['Pclass']==1].shape[0]} person in first class")
print(f"There are {df[df['Pclass']==2].shape[0]} person in second class")
print(f"There are {df[df['Pclass']==3].shape[0]} person in third class")
# Out:
# There are 216 person in first class
# There are 184 person in second class
# There are 491 person in third class

# %%
# another method
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# Number of Male And Female Passengers
print(f"Number of male in titanic is {df[df['Sex']=='male'].shape[0]}")
print(f"Number of female in titanic is {df[df['Sex']=='female'].shape[0]}")
# Out:
# Number of male in titanic is 577
# Number of female in titanic is 314

# %%
# another method
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# #  Biveriate analysis

# %%
# How Has Better Chance of Survival Male or Female?
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
sns.barplot(x='Sex',y='Survived',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
sns.barplot(x='Pclass',y='Survived',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>
